# %% [markdown]
# ##**Objective:**
# Program to train and evaluate a convolutional neural network using Keras Library to classify MNIST fashion dataset. Demonstrate the effect of filter size, regularization, batch size and optimization algorithm on model performance.

# %% [markdown]
# ##**Description of the Model:**
# Import Required Libraries :TensorFlow/Keras: Used to build and train the CNN model.Matplotlib & NumPy: Used for visualization and numerical operations.The model is designed for classifying images from the Fashion MNIST dataset, that contains 10 different clothing categories.
#
# Load and Preprocess the Fashion MNIST Dataset :Loads the Fashion MNIST dataset, which consists of 70,000 images (60,000 for training, 10,000 for testing).Normalizes pixel values to the range [0,1] to speed up training.Reshapes the images from (28,28) to (28,28,1) to match CNN input format (grayscale images with 1 channel)..It consists of multiple convolutional layers. Multiple convolutional is used for automatic feature extraction.
#
# Defining a Function to Create the CNN Model:a. Creates a CNN model with:Two convolutional layers (Conv2D) with ReLU activation.Two max pooling layers (MaxPooling2D) to reduce feature map size.A fully connected layer (Dense) with 128 neurons.An output layer (Dense) with 10 neurons and softmax activation for classification.b. Uses Adam optimizer and sparse categorical cross-entropy loss.Max-pooling layers help in reducing dimensionality while retaining important information.
#
# Fully connected dense layers are used for classification.
#
# The model learns spatial hierarchies of features to distinguish between different clothing items.
#
# The final output layer uses the softmax activation function to predict class probabilities.
#
# The architecture is flexible, allowing hyperparameter tuning to optimize performance.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_sample_images(X, y, class_names):
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(X[i], cmap='gray')
        plt.title(class_names[y[i]])
        plt.axis('off')
    plt.show()

# Load and preprocess data
def load_and_preprocess_data():
    (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

    # Normalize images
    X_train, X_test = X_train / 255.0, X_test / 255.0

    # Reshape for CNN input
    X_train = X_train.reshape(-1, 28, 28, 1)
    X_test = X_test.reshape(-1, 28, 28, 1)

    # Split validation set
    X_val, y_val = X_test[:8000], y_test[:8000]
    X_test, y_test = X_test[8000:], y_test[8000:]

    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# Function to create model
def build_model(filter_size=3, reg=None, optimizer='adam'):
    model = Sequential([
        Conv2D(64, (filter_size, filter_size), activation='relu', padding='same',
               input_shape=(28, 28, 1), kernel_regularizer=reg),
        BatchNormalization(),
        Conv2D(64, (filter_size, filter_size), activation='relu', kernel_regularizer=reg),
        BatchNormalization(),
        MaxPooling2D((2, 2)),

        Conv2D(128, (filter_size, filter_size), activation='relu', padding='same', kernel_regularizer=reg),
        BatchNormalization(),
        Conv2D(128, (filter_size, filter_size), activation='relu', kernel_regularizer=reg),
        BatchNormalization(),
        MaxPooling2D((2, 2)),

        Flatten(),
        Dense(256, activation='relu', kernel_regularizer=reg),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])

    if optimizer == 'adam':
        opt = Adam(learning_rate=0.0001)
    elif optimizer == 'sgd':
        opt = SGD(learning_rate=0.01, momentum=0.9)
    elif optimizer == 'rmsprop':
        opt = RMSprop(learning_rate=0.0001)
    else:
        raise ValueError("Invalid optimizer")

    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

# Train and evaluate model
def train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test, batch_size=64, epochs=20):
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

    # Plot accuracy and loss
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.legend()
    plt.title('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.legend()
    plt.title('Loss')
    plt.show()

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_acc * 100:.2f}%")

    # Predict and plot confusion matrix
    y_pred = np.argmax(model.predict(X_test), axis=1)
    class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']
    plot_confusion_matrix(y_test, y_pred, class_names)

# Run experiments
(X_train, y_train), (X_val, y_val), (X_test, y_test) = load_and_preprocess_data()

# Display sample images
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']
plot_sample_images(X_train.squeeze(), y_train, class_names)

# Experiment with different filter sizes
for size in [3, 5]:
    print(f"Training with filter size {size}")
    model = build_model(filter_size=size)
    train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test)

# Experiment with L2 regularization
for reg in [None, regularizers.l2(0.001)]:
    print(f"Training with L2 Regularization: {reg}")
    model = build_model(reg=reg)
    train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test)

# Experiment with different optimizers
for opt in ['adam', 'sgd', 'rmsprop']:
    print(f"Training with optimizer: {opt}")
    model = build_model(optimizer=opt)
    train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test)

# Experiment with different batch sizes
for batch in [32, 64, 128]:
    print(f"Training with batch size: {batch}")
    model = build_model()
    train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test, batch_size=batch)

print("Experiments completed!")
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training with filter size 3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 64)          │             640 │
# ...

# %% [markdown]
# ##**My Comments:**
# The model performance is well , but due to training loss decreases when validation loss increases , overfitting problem facing .
#
#  To get highest accuracy , i tried many ways like by decreasing & increasing CNN layers , adding droup out 0.5 ,  changing learning rate  ,batch size , number of epochs  etc..  But i did not get success in achieving highest accuracy , validation accuracy .
#
#  --> In my model the validation accuracy increasing in starting epochs but after some epochs the validation accuracy stop increasing and it moving around 89% so i faced problem of overfiting in my model.
#
#
# --> i done experiment with different optimizers like Stochastic Gradient Descent (SGD) , Root Mean Square Propagation (RMSprop),   L2 regularization,different filter sizes, different batch sizes to get the best training performance. .
#
# In my above model i tested using different parameters , Finally i got Test accuracy :- 93.30% (in cases Training with batch size: 32,Training with L2 Regularization: None)  In this 2 cases i got this highest validation accuracy .
#
# **Reasons**,  According To Me Not getting Accuracy More Than 93.30% are as follows:-
#
# 1.Some class pairs (e.g., "Shirt" vs. "T-Shirt") have high inter-class similarity, making classification harder.
#
# 2. Fashion MNIST is more challenging than regular MNIST due to  differences in clothing categories.
#
# **Reasons Why only in this 2 cases get highest Test Accuracy** :-
#
# 1. Larger batches (64, 128) can converge faster, but may not generalize well
#
# 2.Batch 32 balances noise & stability well, leading to optimal generalization.
#
# 3. Adam optimizer worked best → Adaptability helped converge efficiently.
#
# 4.RMSprop sometimes over-adapts and causes overfitting.
#
# 5.L2 regularization (high values like 0.001) forces weights to be small, which can limit the model's learning capacity.
#
# 6.model might not be overfitting, so regularization didn’t provide a significant benefit.
#
# 7.3x3 filters capture fine-grained details without excessive parameter count.
#
# 8.5x5 filters increase parameters, making optimization harder without significantly improving feature extraction.
